# %% [markdown]
# ## file operations

# %%
file = open("my_file1.txt",'w')

# %%
file.write("hello!,\n  welcome to data science class")
# Out:
# 39

# %%
file.close()

# %%
filer = open('my_file1.txt','r')

# %%
filer.readline()
# Out:
# 'hello!,\n'

# %%
filer.readline()
# Out:
# '  welcome to data science class'

# %%
filer.close()

# %%
p = open("python_wiki.txt",'r')

# %%
p.readline()
# Out:
# 'Python combines remarkable power with\n'

# %%
p.readline()
# Out:
# ' very clear syntax. It has modules, classes, exceptions, \n'

# %%
p.read()
# Out:
# 'very high level dynamic data types, and dynamic typing.\n There are interfaces to many system calls and libraries, \nas well as to various windowing systems. \nNew built-in modules are easily written in C or C++ (or other languages,\n depending on the chosen implementation).\n Python is also usable as an extension language for applications \nwritten in other languages that \nneed easy-to-use scripting or automation interfaces.'

# %%
p.close()

# %%
r = open("python_wiki.txt",'r')

my_list = []
for i in r:
    my_list.append(i)
print(my_list)
r.close()
# Out:
# ['Python combines remarkable power with\n', ' very clear syntax. It has modules, classes, exceptions, \n', 'very high level dynamic data types, and dynamic typing.\n', ' There are interfaces to many system calls and libraries, \n', 'as well as to various windowing systems. \n', 'New built-in modules are easily written in C or C++ (or other languages,\n', ' depending on the chosen implementation).\n', ' Python is also usable as an extension language for applications \n', 'written in other languages that \n', 'need easy-to-use scripting or automation interfaces.']

# %%
iris = open("iris.data.txt",'r')
i_class = []
line_item = []
for line in iris:
    line_item = line.split(",")
    print(line_item[0],line_item[-1])
    
iris.close()
# Out:
# 5.1 Iris-setosa
#
# 4.9 Iris-setosa
#
# 4.7 Iris-setosa
#
# 4.6 Iris-setosa
#
# 5.0 Iris-setosa
#
# 5.4 Iris-setosa
#
# 4.6 Iris-setosa
#
# 5.0 Iris-setosa
#
# 4.4 Iris-setosa
#
# 4.9 Iris-setosa
#
# 5.4 Iris-setosa
#
# 4.8 Iris-setosa
#
# 4.8 Iris-setosa
#
# 4.3 Iris-setosa
#
# 5.8 Iris-setosa
#
# 5.7 Iris-setosa
#
# 5.4 Iris-setosa
#
# 5.1 Iris-setosa
#
# 5.7 Iris-setosa
#
# 5.1 Iris-setosa
#
# 5.4 Iris-setosa
#
# 5.1 Iris-setosa
#
# 4.6 Iris-setosa
#
# 5.1 Iris-setosa
#
# 4.8 Iris-setosa
#
# 5.0 Iris-setosa
#
# 5.0 Iris-setosa
#
# 5.2 Iris-setosa
#
# 5.2 Iris-setosa
#
# 4.7 Iris-setosa
#
# 4.8 Iris-setosa
#
# 5.4 Iris-setosa
#
# 5.2 Iris-setosa
#
# 5.5 Iris-setosa
#
# 4.9 Iris-setosa
#
# 5.0 Iris-setosa
#
# 5.5 Iris-setosa
#
# 4.9 Iris-setosa
#
# 4.4 Iris-setosa
#
# 5.1 Iris-setosa
#
# 5.0 Iris-setosa
#
# 4.5 Iris-setosa
#
# 4.4 Iris-setosa
#
# 5.0 Iris-setosa
#
# 5.1 Iris-setosa
#
# 4.8 Iris-setosa
#
# 5.1 Iris-setosa
#
# 4.6 Iris-setosa
#
# 5.3 Iris-setosa
#
# 5.0 Iris-setosa
#
# ...

# %%
ad = open("adult.data.txt",'r')
for line in ad:
    line_i = line.split(",")
    print(line_i[0:3],line_i[-1])
ad.close()
# Out:
# ['39', ' State-gov', ' 77516']  <=50K
#
# ['50', ' Self-emp-not-inc', ' 83311']  <=50K
#
# ['38', ' Private', ' 215646']  <=50K
#
# ['53', ' Private', ' 234721']  <=50K
#
# ['28', ' Private', ' 338409']  <=50K
#
# ['37', ' Private', ' 284582']  <=50K
#
# ['49', ' Private', ' 160187']  <=50K
#
# ['52', ' Self-emp-not-inc', ' 209642']  >50K
#
# ['31', ' Private', ' 45781']  >50K
#
# ['42', ' Private', ' 159449']  >50K
#
# ['37', ' Private', ' 280464']  >50K
#
# ['30', ' State-gov', ' 141297']  >50K
#
# ['23', ' Private', ' 122272']  <=50K
#
# ['32', ' Private', ' 205019']  <=50K
#
# ['40', ' Private', ' 121772']  >50K
#
# ['34', ' Private', ' 245487']  <=50K
#
# ['25', ' Self-emp-not-inc', ' 176756']  <=50K
#
# ['32', ' Private', ' 186824']  <=50K
#
# ['38', ' Private', ' 28887']  <=50K
#
# ['43', ' Self-emp-not-inc', ' 292175']  >50K
#
# ['40', ' Private', ' 193524']  >50K
#
# ['54', ' Private', ' 302146']  <=50K
#
# ['35', ' Federal-gov', ' 76845']  <=50K
#
# ...
